# %% [markdown]
# <a href="https://colab.research.google.com/github/AAkiraYamazaki/PollenCounter-YOLOv5/blob/main/PollenCounter_YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌼 PollenCounter-YOLOv5 — Colab Notebook
#
# (2026/02/14 updated)
#
#  This notebook supports BOTH models:
#    1) pollen germination (germinated / non-germinated)
#    2) pollen viability   (viable / non-viable)
#
# ### Funding:
#  This work was supported by the Research and Implementation Promotion Program through Open Innovation Grants (JPJ011937) from the Bio-oriented Technology Research Advancement Institution (BRAIN), Japan.

# %% [markdown]
# ## 0) Select task

# %%
import ipywidgets as widgets
from IPython.display import display

task_widget = widgets.Dropdown(
    options=["germination", "viability"],
    value="germination",
    description="Task:"
)
display(task_widget)
# Out:
# Dropdown(description='Task:', options=('germination', 'viability'), value='germination')

# %% [markdown]
# **GoogleDriveにマウントする（接続できるようになる）**
# **Googleアカウントの認証が必要**
#
#
# TEST

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **解析用ディレクトリの作成**

# %%
WORKING_DIR = '/content/tmp'
# !mkdir $WORKING_DIR
# %cd $WORKING_DIR
# Out:
# /content/tmp

# %% [markdown]
# ##1)Yolov5のダウンロード

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17817, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 17817 (delta 12), reused 6 (delta 6), pack-reused 17796 (from 3)
# Receiving objects: 100% (17817/17817), 16.96 MiB | 17.65 MiB/s, done.
# Resolving deltas: 100% (12138/12138), done.

# %% [markdown]
# **yolov5の実行に必要なソフトウェアなどをインストール
# （requiment.txtの中身をインストール）**

# %%
# %cd yolov5/
# !pip install -qr requirements.txt
# %cd ../
# Out:
# /content/tmp/yolov5
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 80.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 16.7 MB/s eta 0:00:00
# /content/tmp

# %% [markdown]
# **detect_v2.pyをyolov5ディレクトリ内にコピーする**
#
# 実行する前にdetect_v2.pyが「マイドライブ」内にアップロードできていることを確認する。

# %%
###実行する前にdetect_v2.pyが「マイドライブ」内にアップロードできていることを確認する。

#detect_v2.pyをyolov5ディレクトリ内にコピーするコマンド
# !cp ../drive/MyDrive/detect_v2.py yolov5/

# %% [markdown]
# **画像からの花粉の検出を行う（detect_v2.py）**
# detect_v2.pyを実行する。

# %%
#detect_v2.pyを実行する
#source 以下には解析したいフォルダのpathを入力する。
#２重のフォルダ内にjpgファイルが入っていても解析可能。

# !python yolov5/detect_v2.py --source ../drive/MyDrive/HIGUCHI/ --weight ../drive/MyDrive/best_germination_v3.pt --save-txt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# detect_v2: weights=['../drive/MyDrive/best_germination_v3.pt'], source=../drive/MyDrive/HIGUCHI/, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-450-g781b9d57 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# ...

# %% [markdown]
# **解析結果をダウンロードする**

# %%
# ダウンロードしたいフォルダを zip 圧縮する
# !zip -r /content/download.zip /content/tmp/yolov5/runs/

# 圧縮した zip ファイルをダウンロードする
from google.colab import files
files.download("/content/download.zip")
# Out:
#   adding: content/tmp/yolov5/runs/ (stored 0%)
#   adding: content/tmp/yolov5/runs/detect/ (stored 0%)
#   adding: content/tmp/yolov5/runs/detect/exp/ (stored 0%)
#   adding: content/tmp/yolov5/runs/detect/exp/labels/ (stored 0%)
#   adding: content/tmp/yolov5/runs/detect/exp/labels/20251217_906.txt (deflated 73%)
#   adding: content/tmp/yolov5/runs/detect/exp/labels/20251217_914.txt (deflated 72%)
#   adding: content/tmp/yolov5/runs/detect/exp/results.csv (deflated 28%)
#   adding: content/tmp/yolov5/runs/detect/exp/20251217_914.jpg (deflated 1%)
#   adding: content/tmp/yolov5/runs/detect/exp/20251217_906.jpg (deflated 1%)
